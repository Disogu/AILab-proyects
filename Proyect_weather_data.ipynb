# %% [markdown]
# <a href="https://colab.research.google.com/github/Disogu/AILab-proyects/blob/main/Proyect_weather_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
weather1= pd.read_csv("/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather01.txt" , sep='\s+')
weather1
# Out:
#        X  year  month            measure    X1   X2
# 1      1  2014     12   Max.TemperatureF    64   42
# 2      2  2014     12  Mean.TemperatureF    52   38
# 3      3  2014     12   Min.TemperatureF    39   33
# 4      4  2014     12     Max.Dew.PointF    46   40
# 5      5  2014     12     MeanDew.PointF    40   27
# ..   ...   ...    ...                ...   ...  ...
# 282  282  2015     12  Max.Gust.SpeedMPH    17  NaN
# 283  283  2015     12    PrecipitationIn  0.14  NaN
# 284  284  2015     12         CloudCover     7  NaN
# 285  285  2015     12             Events  Rain  NaN
# 286  286  2015     12     WindDirDegrees   109  NaN
#
# [286 rows x 6 columns]

# %%
import glob
wfiles= sorted(glob.glob('/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather*.txt'))
wfiles
# Out:
# ['/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather01.txt',
#  '/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather02.txt',
#  '/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather03.txt',
#  '/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather04.txt',
#  '/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather05.txt',
#  '/content/drive/MyDrive/Ai_labschool_proyects/Weather_datasets/weather06.txt']

# %%
weather = pd.concat((pd.read_csv(file,sep='\s+') for file in wfiles), axis= 'columns')
weather
# Out:
#        X  year  month            measure    X1   X2   X3   X4   X5   X6  ...  \
# 1      1  2014     12   Max.TemperatureF    64   42   51   43   42   45  ...
# 2      2  2014     12  Mean.TemperatureF    52   38   44   37   34   42  ...
# 3      3  2014     12   Min.TemperatureF    39   33   37   30   26   38  ...
# 4      4  2014     12     Max.Dew.PointF    46   40   49   24   37   45  ...
# 5      5  2014     12     MeanDew.PointF    40   27   42   21   25   40  ...
# ..   ...   ...    ...                ...   ...  ...  ...  ...  ...  ...  ...
# 282  282  2015     12  Max.Gust.SpeedMPH    17  NaN  NaN  NaN  NaN  NaN  ...
# 283  283  2015     12    PrecipitationIn  0.14  NaN  NaN  NaN  NaN  NaN  ...
# 284  284  2015     12         CloudCover     7  NaN  NaN  NaN  NaN  NaN  ...
# 285  285  2015     12             Events  Rain  NaN  NaN  NaN  NaN  NaN  ...
# 286  286  2015     12     WindDirDegrees   109  NaN  NaN  NaN  NaN  NaN  ...
#
# ...

# %%
weather.drop(columns='X', inplace=True)
weather
# Out:
#      year  month            measure    X1   X2   X3   X4   X5   X6   X7  ...  \
# 1    2014     12   Max.TemperatureF    64   42   51   43   42   45   38  ...
# 2    2014     12  Mean.TemperatureF    52   38   44   37   34   42   30  ...
# 3    2014     12   Min.TemperatureF    39   33   37   30   26   38   21  ...
# 4    2014     12     Max.Dew.PointF    46   40   49   24   37   45   36  ...
# 5    2014     12     MeanDew.PointF    40   27   42   21   25   40   20  ...
# ..    ...    ...                ...   ...  ...  ...  ...  ...  ...  ...  ...
# 282  2015     12  Max.Gust.SpeedMPH    17  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 283  2015     12    PrecipitationIn  0.14  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 284  2015     12         CloudCover     7  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 285  2015     12             Events  Rain  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 286  2015     12     WindDirDegrees   109  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
# ...

# %%
wmelt= weather.melt(id_vars=['year','month','measure'])
wmelt
# Out:
#       year  month            measure variable value
# 0     2014     12   Max.TemperatureF       X1    64
# 1     2014     12  Mean.TemperatureF       X1    52
# 2     2014     12   Min.TemperatureF       X1    39
# 3     2014     12     Max.Dew.PointF       X1    46
# 4     2014     12     MeanDew.PointF       X1    40
# ...    ...    ...                ...      ...   ...
# 8861  2015     12  Max.Gust.SpeedMPH      X31   NaN
# 8862  2015     12    PrecipitationIn      X31   NaN
# 8863  2015     12         CloudCover      X31   NaN
# 8864  2015     12             Events      X31   NaN
# 8865  2015     12     WindDirDegrees      X31   NaN
#
# [8866 rows x 5 columns]

# %%
wmelt.variable= wmelt.variable.replace('X','',regex=True).astype(int)
wmelt
# Out:
#       year  month            measure  variable value
# 0     2014     12   Max.TemperatureF         1    64
# 1     2014     12  Mean.TemperatureF         1    52
# 2     2014     12   Min.TemperatureF         1    39
# 3     2014     12     Max.Dew.PointF         1    46
# 4     2014     12     MeanDew.PointF         1    40
# ...    ...    ...                ...       ...   ...
# 8861  2015     12  Max.Gust.SpeedMPH        31   NaN
# 8862  2015     12    PrecipitationIn        31   NaN
# 8863  2015     12         CloudCover        31   NaN
# 8864  2015     12             Events        31   NaN
# 8865  2015     12     WindDirDegrees        31   NaN
#
# [8866 rows x 5 columns]

# %%
wmelt.dropna (inplace=True)
wmelt
# Out:
#       year  month             measure  variable  value
# 0     2014     12    Max.TemperatureF         1     64
# 1     2014     12   Mean.TemperatureF         1     52
# 2     2014     12    Min.TemperatureF         1     39
# 3     2014     12      Max.Dew.PointF         1     46
# 4     2014     12      MeanDew.PointF         1     40
# ...    ...    ...                 ...       ...    ...
# 8816  2015     10  Mean.Wind.SpeedMPH        31    7.0
# 8817  2015     10   Max.Gust.SpeedMPH        31   17.0
# 8818  2015     10     PrecipitationIn        31    0.0
# 8819  2015     10          CloudCover        31    4.0
# 8821  2015     10      WindDirDegrees        31  224.0
#
# [7845 rows x 5 columns]

# %%
wmelt.rename(columns={'variable':'day'}, inplace=True)

# %%
wmelt['date']= pd.to_datetime(wmelt[['year', 'month', 'day']])
wmelt
# Out:
#       year  month             measure  day  value       date
# 0     2014     12    Max.TemperatureF    1     64 2014-12-01
# 1     2014     12   Mean.TemperatureF    1     52 2014-12-01
# 2     2014     12    Min.TemperatureF    1     39 2014-12-01
# 3     2014     12      Max.Dew.PointF    1     46 2014-12-01
# 4     2014     12      MeanDew.PointF    1     40 2014-12-01
# ...    ...    ...                 ...  ...    ...        ...
# 8816  2015     10  Mean.Wind.SpeedMPH   31    7.0 2015-10-31
# 8817  2015     10   Max.Gust.SpeedMPH   31   17.0 2015-10-31
# 8818  2015     10     PrecipitationIn   31    0.0 2015-10-31
# 8819  2015     10          CloudCover   31    4.0 2015-10-31
# 8821  2015     10      WindDirDegrees   31  224.0 2015-10-31
#
# [7845 rows x 6 columns]

# %%
wmelt.drop(['year','month','day'], axis=1 , inplace=True)

# %%
wmelt
# Out:
#                  measure  value       date
# 0       Max.TemperatureF     64 2014-12-01
# 1      Mean.TemperatureF     52 2014-12-01
# 2       Min.TemperatureF     39 2014-12-01
# 3         Max.Dew.PointF     46 2014-12-01
# 4         MeanDew.PointF     40 2014-12-01
# ...                  ...    ...        ...
# 8816  Mean.Wind.SpeedMPH    7.0 2015-10-31
# 8817   Max.Gust.SpeedMPH   17.0 2015-10-31
# 8818     PrecipitationIn    0.0 2015-10-31
# 8819          CloudCover    4.0 2015-10-31
# 8821      WindDirDegrees  224.0 2015-10-31
#
# [7845 rows x 3 columns]

# %%
wf= wmelt.pivot(index='date', columns='measure', values='value').reset_index()
wf
# Out:
# measure       date CloudCover     Events Max.Dew.PointF Max.Gust.SpeedMPH  \
# 0       2014-12-01          6       Rain             46                29
# 1       2014-12-02          7  Rain-Snow             40                29
# 2       2014-12-03          8       Rain             49                38
# 3       2014-12-04          3       Rain             24                33
# 4       2014-12-05          5       Rain             37                26
# ..             ...        ...        ...            ...               ...
# 361     2015-11-27        7.0        NaN           52.0              32.0
# 362     2015-11-28          8       Rain             50                23
# 363     2015-11-29          4        NaN             33                20
# 364     2015-11-30          6        NaN             26                17
# 365     2015-12-01          7       Rain             43                17
#
# measure Max.Humidity Max.Sea.Level.PressureIn Max.TemperatureF  \
# ...

# %%
wf.iloc[0:,1:30]
# Out:
# measure CloudCover     Events Max.Dew.PointF Max.Gust.SpeedMPH Max.Humidity  \
# 0                6       Rain             46                29           74
# 1                7  Rain-Snow             40                29           92
# 2                8       Rain             49                38          100
# 3                3       Rain             24                33           69
# 4                5       Rain             37                26           85
# ..             ...        ...            ...               ...          ...
# 361            7.0        NaN           52.0              32.0        100.0
# 362              8       Rain             50                23           93
# 363              4        NaN             33                20           79
# 364              6        NaN             26                17           75
# 365              7       Rain             43                17           96
#
# ...

# %%
wf['Events'].value_counts()
# Out:
# Events
# Rain                          90
# Snow                          31
# Rain-Snow                     10
# Fog-Rain                       8
# Fog-Snow                       7
# Fog                            6
# Fog-Rain-Snow                  4
# Rain-Thunderstorm              4
# Fog-Rain-Thunderstorm          3
# Thunderstorm                   1
# Fog-Rain-Hail-Thunderstorm     1
# Name: count, dtype: int64

# %%
fcol = wf.columns.map('-'.join)
fcol
# Out:
# Index(['d-a-t-e', 'C-l-o-u-d-C-o-v-e-r', 'E-v-e-n-t-s',
#        'M-a-x-.-D-e-w-.-P-o-i-n-t-F', 'M-a-x-.-G-u-s-t-.-S-p-e-e-d-M-P-H',
#        'M-a-x-.-H-u-m-i-d-i-t-y',
#        'M-a-x-.-S-e-a-.-L-e-v-e-l-.-P-r-e-s-s-u-r-e-I-n',
#        'M-a-x-.-T-e-m-p-e-r-a-t-u-r-e-F',
#        'M-a-x-.-V-i-s-i-b-i-l-i-t-y-M-i-l-e-s',
#        'M-a-x-.-W-i-n-d-.-S-p-e-e-d-M-P-H', 'M-e-a-n-.-H-u-m-i-d-i-t-y',
#        'M-e-a-n-.-S-e-a-.-L-e-v-e-l-.-P-r-e-s-s-u-r-e-I-n',
#        'M-e-a-n-.-T-e-m-p-e-r-a-t-u-r-e-F',
#        'M-e-a-n-.-V-i-s-i-b-i-l-i-t-y-M-i-l-e-s',
#        'M-e-a-n-.-W-i-n-d-.-S-p-e-e-d-M-P-H', 'M-e-a-n-D-e-w-.-P-o-i-n-t-F',
#        'M-i-n-.-D-e-w-p-o-i-n-t-F', 'M-i-n-.-H-u-m-i-d-i-t-y',
#        'M-i-n-.-S-e-a-.-L-e-v-e-l-.-P-r-e-s-s-u-r-e-I-n',
#        'M-i-n-.-T-e-m-p-e-r-a-t-u-r-e-F',
#        'M-i-n-.-V-i-s-i-b-i-l-i-t-y-M-i-l-e-s',
#        'P-r-e-c-i-p-i-t-a-t-i-o-n-I-n', 'W-i-n-d-D-i-r-D-e-g-r-e-e-s'],
#       dtype='object', name='measure')

# %%
wflat= (
    wf.set_axis(fcol,axis=1).reset_index()
)
wflat
# Out:
# measure  index    d-a-t-e C-l-o-u-d-C-o-v-e-r E-v-e-n-t-s  \
# 0            0 2014-12-01                   6        Rain
# 1            1 2014-12-02                   7   Rain-Snow
# 2            2 2014-12-03                   8        Rain
# 3            3 2014-12-04                   3        Rain
# 4            4 2014-12-05                   5        Rain
# ..         ...        ...                 ...         ...
# 361        361 2015-11-27                 7.0         NaN
# 362        362 2015-11-28                   8        Rain
# 363        363 2015-11-29                   4         NaN
# 364        364 2015-11-30                   6         NaN
# 365        365 2015-12-01                   7        Rain
#
# measure M-a-x-.-D-e-w-.-P-o-i-n-t-F M-a-x-.-G-u-s-t-.-S-p-e-e-d-M-P-H  \
# 0                                46                                29
# 1                                40                                29
# ...

# %%
wmelt.pivot(index='date',columns='measure').reset_index()
# Out:
#               date      value                                              \
# measure            CloudCover     Events Max.Dew.PointF Max.Gust.SpeedMPH
# 0       2014-12-01          6       Rain             46                29
# 1       2014-12-02          7  Rain-Snow             40                29
# 2       2014-12-03          8       Rain             49                38
# 3       2014-12-04          3       Rain             24                33
# 4       2014-12-05          5       Rain             37                26
# ..             ...        ...        ...            ...               ...
# 361     2015-11-27        7.0        NaN           52.0              32.0
# 362     2015-11-28          8       Rain             50                23
# 363     2015-11-29          4        NaN             33                20
# 364     2015-11-30          6        NaN             26                17
# 365     2015-12-01          7       Rain             43                17
#
# ...

# %%
wf['Max.TemperatureF']
# Out:
# 0        64
# 1        42
# 2        51
# 3        43
# 4        42
#        ...
# 361    64.0
# 362      60
# 363      44
# 364      38
# 365      45
# Name: Max.TemperatureF, Length: 366, dtype: object

# %%
import matplotlib.dates as mdates

for col in ['Max.TemperatureF', 'Min.TemperatureF', 'Mean.TemperatureF']:
    wf[col] = pd.to_numeric(wf[col], errors='coerce')

plt.figure(figsize=(15, 6))

plt.plot(wf['date'], wf['Max.TemperatureF'], label='Max Temperature', marker='o', linestyle='-')
plt.plot(wf['date'], wf['Min.TemperatureF'], label='Min Temperature', marker='o', linestyle='-')
plt.plot(wf['date'], wf['Mean.TemperatureF'], label='Mean Temperature', marker='o', linestyle='-')

plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gcf().autofmt_xdate()

plt.xlabel('Date')
plt.ylabel('Temperature (°F)')
plt.title('Temperature vs. Date')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

def predict_next_day_temperature(df, column_name, n_values):

    predictions = {}
    for col in target_cols:
        # Prepare data for linear regression
        X = np.arange(n_values).reshape(-1,1)
        y = df[column_name].tail(n_values).values

        # Train linear regression model
        model = LinearRegression()
        model.fit(X, y)
        next_t=n_values
        next_val=model.predict([[next_t]])
        return next_val

# Example usage (assuming 'wf' DataFrame is available):
target_cols = ['Max.TemperatureF', 'Min.TemperatureF', 'Mean.TemperatureF']
next_day_temps = predict_next_day_temperature(wf,target_cols,10)
predTemp=pd.DataFrame(next_day_temps, columns=target_cols)
predTemp
# Out:
#    Max.TemperatureF  Min.TemperatureF  Mean.TemperatureF
# 0         48.533333         34.666667               41.8
